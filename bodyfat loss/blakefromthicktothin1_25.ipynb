# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
bodyfat = pd.read_csv("Bodyfat.csv")
bodyfat
# Out:
#      Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
standaterdmaledayburn = pd.read_csv("weightlossmen.csv")
standaterdmaledayburn
# Out:
#     Weight(pounds)  Calories burned after 8 hours of sitting  \
# 0              100                                       500
# 1              120                                       543
# 2              140                                       587
# 3              160                                       631
# 4              180                                       674
# 5              200                                       718
# 6              220                                       761
# 7              240                                       805
# 8              260                                       849
# 9              280                                       892
# 10             300                                       936
#
#     Calories burned after 4 hours of sitting and 4 hours of standing  \
# 0                                                 762
# 1                                                 828
# ...

# %%
femaledayburn= pd.read_csv("weightlosswomen.csv")
femaledayburn
# Out:
#     Weight(pounds)  Calories burned after 8 hours of sitting  \
# 0              100                                       453
# 1              120                                       484
# 2              140                                       514
# 3              160                                       545
# 4              180                                       575
# 5              200                                       606
# 6              220                                       636
# 7              240                                       667
# 8              260                                       697
# 9              280                                       727
# 10             300                                       758
#
#     Calories burned after 4 hours of sitting and 4 hours of standing  \
# 0                                                 691
# 1                                                 737
# ...

# %%
winpounds = 120

HR = 120

W = 120/2.2046

A = 25

T = 1


Malecaloricburn = ((-55.0969 + (0.6309 * HR) + (0.1988 * W) + (0.2017 * A))/4.184) * 60 * T
#Femalecaloricburn = ((-20.4022 + (0.4472 x HR) - (0.1263 x W) + (0.074 x A))/4.184) x 60 x T
    
Malecaloricburn
# Out:
# 523.0584696104737

# %%
hoursslept= 12

hoursstanding= 4 

hoursworkingout= T
index=[]
Hourssitting = 3
if winpounds.value is <= 100
  index.append(0)
    else 

 


totalhoursresting= Hourssitting + hoursslept

caloriesburnedworkingout= Malecaloricburn

caloriessitting=[]
tdf= standaterdmaledayburn.ix[0,'Weight(pounds)']
tdf
# Out:
# /Users/blakewilfong/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# 100
